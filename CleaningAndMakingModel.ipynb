# %%
import pandas as pd
import numpy as np
import os
import sklearn 
import requests

# %%
import requests
import json

 # Function to fetch image path for a given TV show ID
def fetch_image_path(tv_id=None):
    # API details
    image_url_template = "https://api.themoviedb.org/3/movie/{tv_id}/images"
    
    api_key = "2d93afa4fe9bcb72ba4e36370e670b79"

    # Discover the most popular TV show if tv_id is not provided
    if tv_id is None:
        params = {
            "api_key": api_key,
            "language": "en-US",
            "sort_by": "popularity.desc",
        }

    # Fetch images for the TV show
    image_url = image_url_template.format(tv_id=tv_id)
    image_response = requests.get(image_url, params={"api_key": api_key})
    if image_response.status_code == 200:
        image_data = image_response.json()
        if "posters" in image_data and image_data["posters"]:
            file_path = image_data["posters"][0]["file_path"]
            full_url = f"https://image.tmdb.org/t/p/original{file_path}"
            return full_url
        else:
            raise Exception("No posters found for this TV show.")
    else:
        raise Exception(f"Failed to fetch images. Status code: {image_response.status_code}")

fetch_image_path(tv_id=15)
# Out:
# 'https://image.tmdb.org/t/p/original/sav0jxhqiH0bPr2vZFU0Kjt2nZL.jpg'

# %%
import requests

# API details
api_key = "2d93afa4fe9bcb72ba4e36370e670b79"
movie_id = 27205
language = "en-US"

# Construct the URL
url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
params = {
    "api_key": api_key,
    "language": language
}

# Make the API request
insert_id_inUrl = url.format(movie_id = movie_id)
response = requests.get(insert_id_inUrl, params={"api_key": api_key})

# Handle the response
if response.status_code == 200:
    data = response.json()
    poster = data['posters'][1]
    poster_file_path = poster['file_path']
    image_path = f"https://image.tmdb.org/t/p/w500/{poster_file_path}" # 1E5baAaEse26fej7uHcjOgEE2t2.jpg
    print(image_path)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# https://image.tmdb.org/t/p/w500//oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg

# %%
from IPython.display import Image, display

# Display the image inline
#f posters:
display(Image(url=poster['file_path']))
# Out:
# <img src="/oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg"/>

# %%
from PIL import Image
from io import BytesIO

# Fetch the image
if poster:
    image_response = requests.get(f"https://image.tmdb.org/t/p/w500/{poster['file_path']}")
    if image_response.status_code == 200:
        img = Image.open(BytesIO(image_response.content))
        img.show()  # This opens the image in the default viewer
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 6
#       4 # Fetch the image
#       5 if poster:
# ----> 6     image_response = requests.get(f"https://image.tmdb.org/t/p/w500/{poster['file_path']}")
#       7     if image_response.status_code == 200:
#       8         img = Image.open(BytesIO(image_response.content))
#
# File c:\Users\JASIM\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
img = Image.open(BytesIO(image_path))
img.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 img = Image.open(BytesIO(image_path))
#       2 img.show()
#
# TypeError: a bytes-like object is required, not 'str'

# %%
#def fetch_images(movie_id):
    
api_key = "2d93afa4fe9bcb72ba4e36370e670b79"
image_url_template = "https://api.themoviedb.org/3/movie/{movie_id}/images"


#if collection_id is None:
params = {
    "api_key": api_key,
    "language": "en-US",
    "sort_by": "popularity.desc",
}

urlformat = image_url_template.format(movie_id = movie_ids)

request = requests.get(urlformat, params=params)

if request.status_code == 200:
    data = request.json()
    poster = data['posters']
    for i in poster:
# Out:
#   Cell In[1], line 22
#
#     ^
# SyntaxError: incomplete input

# %%
fetch_images(27205)
# Out:
# 27205

# %%
movie_ids = df_details['id'][0]

# %%
df_details = pd.read_csv("movies_details.csv")
df_credits = pd.read_csv("movies_credits.csv")

# %%
df_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10003 entries, 0 to 10002
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  10003 non-null  bool
#  1   backdrop_path          9992 non-null   object
#  2   belongs_to_collection  2495 non-null   object
#  3   budget                 10003 non-null  int64
#  4   genres                 10003 non-null  object
#  5   homepage               4335 non-null   object
#  6   id                     10003 non-null  int64
#  7   imdb_id                9996 non-null   object
#  8   origin_country         10003 non-null  object
#  9   original_language      10003 non-null  object
#  10  original_title         10003 non-null  object
#  11  overview               10001 non-null  object
#  12  popularity             10003 non-null  float64
#  13  poster_path            9997 non-null   object
# ...

# %%
df_details['poster_path']
# Out:
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4        /3E53WEZJqP6aM84D8CckXx4pIHw.jpg
#                        ...
# 9998     /ih0727BoT24cg87aOVfppZyqzNQ.jpg
# 9999     /vUt2cKOVPUwXJr07TiCqJuTysfD.jpg
# 10000    /7YRO2Jamqb6ck5vJqrwWgMFWuPW.jpg
# 10001    /yAogxeovs5HpzhD4UbrDsSybtp7.jpg
# 10002    /71JMWqNDRz2Au59JYosfn5W8nuS.jpg
# Name: poster_path, Length: 10003, dtype: object

# %%
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10003 entries, 0 to 10002
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10003 non-null  int64
#  1   cast    10003 non-null  object
#  2   crew    10003 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 234.6+ KB

# %% [markdown]
# ### Creating new dataframe from important columns

# %%
# combining two dataframe together
new_df = pd.merge(df_details, df_credits, on = 'id')

# %%
new_df.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'origin_country', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
movies = new_df[['id', 'original_language', 'tagline', 'title', 'genres', 'overview', 'production_companies', 'production_countries', 'cast', 'crew']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10055 entries, 0 to 10054
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10055 non-null  int64
#  1   original_language     10055 non-null  object
#  2   tagline               8446 non-null   object
#  3   title                 10055 non-null  object
#  4   genres                10055 non-null  object
#  5   overview              10053 non-null  object
#  6   production_companies  10055 non-null  object
#  7   production_countries  10055 non-null  object
#  8   cast                  10055 non-null  object
#  9   crew                  10055 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 785.7+ KB

# %% [markdown]
# ## Cleaning The Data

# %%
movies.isnull().sum()
# Out:
# id                         0
# original_language          0
# tagline                 1609
# title                      0
# genres                     0
# overview                   2
# production_companies       0
# production_countries       0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# C:\Users\JASIM\AppData\Local\Temp\ipykernel_16644\3786870272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies = movies.reset_index(drop=True)

# %%
movies['id'].duplicated().sum()
# Out:
# 75

# %%
movies['id'] = movies['id'].drop_duplicates()

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8445 entries, 0 to 8444
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    8370 non-null   float64
#  1   original_language     8445 non-null   object
#  2   tagline               8445 non-null   object
#  3   title                 8445 non-null   object
#  4   genres                8445 non-null   object
#  5   overview              8445 non-null   object
#  6   production_companies  8445 non-null   object
#  7   production_countries  8445 non-null   object
#  8   cast                  8445 non-null   object
#  9   crew                  8445 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 659.9+ KB

# %% [markdown]
# ## Now Fetching data from string list and dict

# %%
# This function will fetch the data from some coulmns 
import ast

def fetchname(obj):
    try:
        list = []
        data = ast.literal_eval(obj)
        #if isinstance(data, dict) and "name" in data:
        for i in data:
            list.append(i.get("name"))
            #list.append(i["name"])
    except (KeyError, TypeError):
        return None
    return list

# %% [markdown]
# #### Fetching Genres of each movies

# %%
fetchname("[{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}]")
# Out:
# ['Drama', 'Action', 'Crime', 'Thriller']

# %%
movies['genres'] = movies['genres'].apply(fetchname)

# %% [markdown]
# #### Fetching Production Companies Names

# %%
movies['production_countries'][0]
# Out:
# "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]"

# %%
movies['production_companies'].apply(fetchname)
# Out:
# 0       [Legendary Pictures, Syncopy, Warner Bros. Pic...
# 1       [Legendary Pictures, Syncopy, Lynda Obst Produ...
# 2       [DC, Legendary Pictures, Syncopy, Isobel Griff...
# 3       [Dune Entertainment, Lightstorm Entertainment,...
# 4       [20th Century Fox, The Donners' Company, Genre...
#                               ...
# 8440      [Gaumont, Kairos, Canal+, TF1 Films Production]
# 8441    [Pathé Entertainment, Ufland, Metro-Goldwyn-Ma...
# 8442    [Relativity Media, Phoenix Pictures, Rising St...
# 8443    [Watchout Studio, TVN Group, Next Film, ITI Ne...
# 8444                [Indigo Film, France 2 Cinéma, Pathé]
# Name: production_companies, Length: 8445, dtype: object

# %%
fetchname(movies['production_countries'][0])
# Out:
# ['United Kingdom', 'United States of America']

# %%
movies['production_countries'] = movies['production_countries'].apply(fetchname)

# %%
movies['production_companies'] = movies['production_companies'].apply(fetchname)

# %%
def director_name(crew):
    list = []
    for crew in ast.literal_eval(crew):
        if crew['job'] == 'Director':
            dict_of_director = crew['name']
            #print(i['job'] == 'Director')
            list.append(dict_of_director)
    return list

# %%
director_name(movies['crew'][0])
# Out:
# ['Christopher Nolan']

# %%
movies['crew'] = movies['crew'].apply(director_name)

# %% [markdown]
# ### Fetching Actors Names

# %%
def fetch_actor(cast):
    name = []
    count = 0
    for actor in ast.literal_eval(cast):
        if count <= 3:
            name.append(actor['name'])
            count += 1
        else:
            break
    return name

# %%
fetch_actor(movies['cast'][0])
# Out:
# ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ken Watanabe', 'Tom Hardy']

# %%
movies['cast'] = movies['cast'].apply(fetch_actor,)

# %% [markdown]
# ### Transformation of columns to lists

# %%
movies.head()
# Out:
#          id original_language  \
# 0   27205.0                en
# 1  157336.0                en
# 2     155.0                en
# 3   19995.0                en
# 4  293660.0                en
#
#                                              tagline            title  \
# 0               Your mind is the scene of the crime.        Inception
# 1  Mankind was born on Earth. It was never meant ...     Interstellar
# 2                  Welcome to a world without rules.  The Dark Knight
# 3                        Enter the world of Pandora.           Avatar
# 4                                     Feel the love.         Deadpool
#
#                                           genres  \
# 0           [Action, Science Fiction, Adventure]
# 1            [Adventure, Drama, Science Fiction]
# 2               [Drama, Action, Crime, Thriller]
# 3  [Action, Adventure, Fantasy, Science Fiction]
# 4                    [Action, Adventure, Comedy]
#
# ...

# %%
#movies['original_country'].apply(lambda x: x.split())
movies['original_language'] = movies['original_language'].apply(lambda x: x.split())
movies['tagline'] = movies['tagline'].apply(lambda x: x.split())
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %% [markdown]
# ### Now removing between each words

# %%
# Removing the spaces
movies['crew'] = movies['crew'].map(lambda x: [i.replace(' ', '') for i in x])
movies['genres'] = movies['genres'].map(lambda x: [i.replace(' ', '') for i in x])
movies['production_companies'] = movies['production_companies'].map(lambda x: [i.replace(' ', '') for i in x])
movies['cast'] = movies['cast'].map(lambda x: [i.replace(' ', '') for i in x])
#movies['crew'].map(lambda x: [i.replace(' ', '') for i in x])

# %% [markdown]
# ***Making new columns to combine all the columns in one single column***

# %%
movies['tags'] = movies['tagline'] + movies['genres'] + movies['overview'] + movies['original_language'] + movies['production_companies'] + movies['production_countries'] + movies['cast'] + movies['crew']

# %%
movies['tags'][0]
# Out:
# ['Your',
#  'mind',
#  'is',
#  'the',
#  'scene',
#  'of',
#  'the',
#  'crime.',
#  'Action',
#  'ScienceFiction',
#  'Adventure',
#  'Cobb,',
#  'a',
#  'skilled',
#  'thief',
#  'who',
#  'commits',
#  'corporate',
#  'espionage',
#  'by',
#  'infiltrating',
#  'the',
#  'subconscious',
#  'of',
#  'his',
#  'targets',
#  'is',
#  'offered',
#  'a',
#  'chance',
#  'to',
#  'regain',
#  'his',
#  'old',
#  'life',
#  'as',
#  'payment',
#  'for',
#  'a',
#  'task',
#  'considered',
#  'to',
#  'be',
#  'impossible:',
#  '"inception",',
#  'the',
#  'implantation',
#  'of',
#  'another',
#  "person's",
#  'idea',
#  'into',
#  'a',
#  "target's",
#  'subconscious.',
#  'en',
#  'LegendaryPictures',
#  'Syncopy',
#  'WarnerBros.Pictures',
#  'United Kingdom',
#  'United States of America',
#  'LeonardoDiCaprio',
#  'JosephGordon-Levitt',
#  'KenWatanabe',
#  'TomHardy',
#  'ChristopherNolan']

# %%
# I'm going to seperate some coluumns from the rest
newdf = movies[['id', 'title', 'tags']]

# %%
newdf.head()
# Out:
#          id            title  \
# 0   27205.0        Inception
# 1  157336.0     Interstellar
# 2     155.0  The Dark Knight
# 3   19995.0           Avatar
# 4  293660.0         Deadpool
#
#                                                 tags
# 0  [Your, mind, is, the, scene, of, the, crime., ...
# 1  [Mankind, was, born, on, Earth., It, was, neve...
# 2  [Welcome, to, a, world, without, rules., Drama...
# 3  [Enter, the, world, of, Pandora., Action, Adve...
# 4  [Feel, the, love., Action, Adventure, Comedy, ...

# %% [markdown]
# ***Tags into lower case***

# %%
# Transform the tags into lower case
newdf['tags'].apply(lambda x: [i.lower() for i in x])
# Out:
# 0       [your, mind, is, the, scene, of, the, crime., ...
# 1       [mankind, was, born, on, earth., it, was, neve...
# 2       [welcome, to, a, world, without, rules., drama...
# 3       [enter, the, world, of, pandora., action, adve...
# 4       [feel, the, love., action, adventure, comedy, ...
#                               ...
# 8440    [if, you, can't, remember, your, past...you, c...
# 8441    [in, 1984,, betty, mahmoody's, husband, took, ...
# 8442    [time, brings, all, things, to, light., drama,...
# 8443    [times, change., the, stakes, remain, the, sam...
# 8444    [everything, is, not, enough., drama, internat...
# Name: tags, Length: 8445, dtype: object

# %%
newdf['tags'] = newdf['tags'].apply(lambda x: [i.lower() for i in x])
# Out:
# C:\Users\JASIM\AppData\Local\Temp\ipykernel_16644\1998774524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['tags'] = newdf['tags'].apply(lambda x: [i.lower() for i in x])

# %%
# Convert the tags list into strings
newdf['tags'].apply(lambda x: " ".join(x))
# Out:
# 0       your mind is the scene of the crime. action sc...
# 1       mankind was born on earth. it was never meant ...
# 2       welcome to a world without rules. drama action...
# 3       enter the world of pandora. action adventure f...
# 4       feel the love. action adventure comedy the ori...
#                               ...
# 8440    if you can't remember your past...you can't sa...
# 8441    in 1984, betty mahmoody's husband took his wif...
# 8442    time brings all things to light. drama thrille...
# 8443    times change. the stakes remain the same drama...
# 8444    everything is not enough. drama internationall...
# Name: tags, Length: 8445, dtype: object

# %%
newdf['tags'] = newdf['tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\JASIM\AppData\Local\Temp\ipykernel_16644\2433798782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['tags'] = newdf['tags'].apply(lambda x: " ".join(x))

# %% [markdown]
# ***Now we are going to apply some other import methods such as stemming and victorization and so on to prepate it***

# %% [markdown]
# ## Stemming

# %%
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

# %%
def stem(text):
    list = []
    for i in text.split():
        list.append(stemmer.stem(i))
        
    return " ".join(list)

# %%
stem(newdf['tags'][0])
# Out:
# 'your mind is the scene of the crime. action sciencefict adventur cobb, a skill thief who commit corpor espionag by infiltr the subconsci of hi target is offer a chanc to regain hi old life as payment for a task consid to be impossible: "inception", the implant of anoth person\' idea into a target\' subconscious. en legendarypictur syncopi warnerbros.pictur unit kingdom unit state of america leonardodicaprio josephgordon-levitt kenwatanab tomhardi christophernolan'

# %%
newdf['tags'] = newdf['tags'].apply(stem)
# Out:
# C:\Users\JASIM\AppData\Local\Temp\ipykernel_16644\2040093980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['tags'] = newdf['tags'].apply(stem)

# %% [markdown]
# ## Victoriazations

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=7000, stop_words='english')

# %%
vectors = cv.fit_transform(newdf['tags']).toarray()

# %%
cv.get_feature_names_out()[10:50]
# Out:
# array(['1492pictur', '15', '150', '16', '17', '17th', '18', '18th', '19',
#        '1920', '1920s', '1930', '1940', '1941', '1942', '1943', '1944',
#        '1945', '1950', '1950s', '1959', '1960', '1960s', '1962', '1964',
#        '1965', '1967', '1970', '1970s', '1972', '1973', '1974', '1976',
#        '1977', '1978', '1980', '1980s', '1984', '1985', '1986'],
#       dtype=object)

# %%
vectors.shape
# Out:
# (8445, 7000)

# %% [markdown]
# ## Cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (8445, 8445)

# %% [markdown]
# ### Functiona for similarity Score

# %%
indx  = newdf[newdf['title'] == 'Avatar'].index
newdf.iloc[indx]
# Out:
#         id   title                                               tags
# 3  19995.0  Avatar  enter the world of pandora. action adventur fa...

# %%
sorted(list(enumerate(similarity[1])), reverse = True, key = lambda x: x[1])[1:6]
# Out:
# [(6695, 0.36329950727537746),
#  (132, 0.3583914681524164),
#  (648, 0.34806170919108287),
#  (6648, 0.3478327964999673),
#  (2711, 0.3442651863295482)]

# %%
newdf.iloc[6695]['title']
# Out:
# 'Space Chimps'

# %%
def similarity_score(title):
    indx = newdf[newdf['title'] ==  title].index
    similar_array = similarity[indx][0]
    fivesimilar_array = sorted(list(enumerate(similar_array)), reverse = True, key = lambda x: x[1])[1:6]
    
    for i in fivesimilar_array:
        five_movies = newdf.iloc[i[0]]['title']
        print(five_movies)

# %%
similarity_score('Avatar')
# Out:
# Avatar: The Way of Water
# Skylines
# Krull
# MirrorMask
# Aliens in the Attic

# %%
similarity_score('Deadpool')
# Out:
# The Wolverine
# Bo Burnham: Make Happy
# Deadpool 2
# Once Upon a Deadpool
# Deadpool & Wolverine

# %%
newdf['title']
# Out:
# 0                     Inception
# 1                  Interstellar
# 2               The Dark Knight
# 3                        Avatar
# 4                      Deadpool
#                  ...
# 8440       Empire of the Wolves
# 8441    Not Without My Daughter
# 8442         All the King's Men
# 8443           The Coldest Game
# 8444                       Loro
# Name: title, Length: 8445, dtype: object

# %%
import pickle
with open('Recommendation_system.pkl', 'wb') as f:
    pickle.dump(similarity, f)

# %%
with open("recommendation_data.pkl", 'wb') as f:
    pickle.dump(newdf, f)

# %%
with open('Recommendation_system.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
def load_data():
    try:
        with open('Recommendation_system.pkl', 'rb') as f:
            return pickle.load(f)
    except FileNotFoundError:
        print("Data not found. Please preprocess the data first.")
        return None
    
mod = load_data()

# %%
def scor(title):
    indx = newdf[newdf['title'] ==  title].index
    similar_array = mod[indx][0]
    fivesimilar_array = sorted(list(enumerate(similar_array)), reverse = True, key = lambda x: x[1])[1:6]
    
    for i in fivesimilar_array:
        five_movies = newdf.iloc[i[0]]['title']
        print(five_movies)

# %%
scor('Superman')
# Out:
# Superman II: The Richard Donner Cut
# Superman II
# All Star Superman
# Superman Returns
# Extraction
